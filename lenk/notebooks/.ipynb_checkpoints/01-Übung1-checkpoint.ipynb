# %% [markdown]
# # Aufgaben der Übung 1
#
#
# ## Aufgabe 1
# ## a)

# %%
import numpy as np

# %%
h = 6.626070040e-34
k = 1.38064852e-23
c = 299792458
s = 5.6703667e-08

# %%
s1 = (2*np.pi**5*k**4) / (15*h**3*c**2)

# %%
print("absolute Abweichung = {} W m^-2 K^-4".format(s1-s))
print("relative Abweichung = {} %".format((s1/s-1) *100))
# Out:
# absolute Abweichung = 1.16083269398e-15 W m^-2 K^-4
# relative Abweichung = 2.04719157182e-06 %

# %% [markdown]
# ## Aufgabe 2

# %%
def M(l,T):
    L = ((2.0*np.pi * h * c**2) / (l**5)) * (np.exp((h*c)/(l*k*T))-1)**-1
    return L

# %%
def planck(l,T):
    L=2.0*np.pi*h*c**2/l**5/(np.exp(h*c/(wlen*k*temp))-1.0)
    return L

# %%
L = np.arange(0.2e-6,10.1e-6,0.1e-6)
#L = np.arange(0.2,4.1,0.1)
T = np.arange(1800,6800,1000)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig,ax = plt.subplots(1,1,figsize=(12,8))

for t in T:
    L_T = []
    for l in L:
        L_T.append(M(l,t))
    
    ax.plot(L,L_T,label="T = {} K".format(t))
    
ax.legend()
ax.set_xlabel(u"λ / µm")
ax.set_ylabel(u"W / (m² * µm)")
# Out:
# Text(0,0.5,u'W / (m\xb2 * \xb5m)')

# %%
L_T
# Out:
# []

# %%
1/(np.exp(3623.2)-1)
# Out:
# /vols/talos/local/anaconda2-5.0.0/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in exp
#   """Entry point for launching an IPython kernel.
# 0.0

# %%
L_sonne = []

for l in L:
    L_sonne.append(M(l,5778))

# %%
L_sonne
# Out:
# [4578831794260.167,
#  38264500219718.16,
#  72452008652435.58,
#  82861471747495.06,
#  77060075243207.5,
#  65349854252773.12,
#  53161342031104.27,
#  42507746316732.8,
#  33824134744033.91,
#  26956602749827.637,
#  21589300772597.793,
#  17405167984518.727,
#  14135574669146.709,
#  11567710628192.975,
#  9537963716794.273,
#  7922153956512.81,
#  6626407274140.001,
#  5579697144726.653,
#  4728086759823.621,
#  4030401388214.971,
#  3455015254653.005,
#  2977476450568.64,
#  2578751207860.114,
#  2243922481774.1787,
#  1961221096048.753,
#  1721300634871.5012,
#  1516691570788.971,
#  1341387787825.2517,
#  1190531417439.4094,
#  1060171097480.1642,
#  947075393200.9962,
#  848587912626.6737,
#  762514128046.0208,
#  687032453073.7096,
#  620623985079.6971,
#  562016694051.3422,
#  510140855382.8718,
#  464093281768.82275,
#  423108477376.2107]

# %%
fig,ax = plt.subplots(1,1,figsize=(16,10))
ax.plot(L,L_sonne)
