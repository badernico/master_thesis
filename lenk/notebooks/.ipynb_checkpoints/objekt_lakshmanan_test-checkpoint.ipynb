# %% [markdown]
# # Versuch den modifizierten Watershed-Segmentierungsansatz nach Laskhaman

# %% [markdown]
# Zunächst müssen wir ein paar Pakete laden.

# %%
# %load_ext Cython

import numpy as np

import scipy.ndimage.filters as filters
import scipy.ndimage as ndi
from skimage import morphology as skmor
import datetime as dt

import l15_msevi.msevi as msv
from analysis_tools import segmentation as sgm

import cython

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Zunächst definieren wir die nötigen Funktionen.

# %% [markdown]
# Nun die Funktionen für den erweiterten Watershed-Algorithmus.
#
# Zuerst die Funktion, um eine Matrix zu quantisieren.

# %%
def quantise_field(field,lower_limit,upper_limit,delta):
    """
    Quantises a given array into discrete steps within given limits and step width.
    
    Parameters
    ----------
    field: numpy array, 2d
        array to quantise
    limit1: float
        first limit for the quantisation
    limit2: float
        second limit for the quantisation
    delta: float
        width of the quantisation steps, if delta > 0 the quantisation will be based on the field maxima and if it
        it < 0 on the field minima
    """
    
    quant = np.zeros_like(field)
    
    too_small = np.where(field <= lower_limit)
    too_large = np.where(field > upper_limit)
    right = np.where(np.logical_and(field > lower_limit,field <= upper_limit) )
    
    if delta < 0:
        quant[too_small] = np.rint((lower_limit-upper_limit)/delta)
        quant[too_large] = 0
        quant[right] = np.rint((field[right] - upper_limit) / delta)
        
        return quant
    elif delta > 0:
        quant[too_large] = np.rint((upper_limit-lower_limit)/delta)
        quant[too_small] = 0
        quant[right] = np.rint((field[right] - lower_limit) / delta)
        
        return quant
    else:
        print("Impossible combination. If limit1 > limit2, delta has to be < 0 and if limit1 < limit2, delta has to be negative.")
        return

# %% [markdown]
# Dann die Funktion, um die benötigte Datenstruktur zu erstellen.

# %%
def create_structure(quantised_array,max_level):
    pixels = {l:[] for l in range(int(max_level)+1)}
    
    shape = quantised_array.shape
    
    for i,pixel in enumerate(quantised_array.ravel()):
        pixels[int(pixel)].append(np.unravel_index(i,shape))
        
    return pixels

# %% [markdown]
# Nun die Funktionen für den erweiterten Watershed-Algorithmus. Da dafür alle Pixel einzeln durchlaufen weden müssen,
# versuchen wir mal eine Cython-Funktion zu erstellen.

# %%
# %%cython
# cimport numpy as np
# import numpy as np
# DFLOAT = np.float
# DINT = np.int
# ctypedef np.float_t DFLOAT_t
# ctypedef np.int_t DINT_t
#
#
# #@cython.boundscheck(False)
# cpdef np.ndarray[DFLOAT_t, ndim=2] capture_basin(np.ndarray[DFLOAT_t, ndim=2] basins,
#                                                  np.ndarray[DFLOAT_t, ndim=2] quantised_array,
#                                                  float center_col, float center_row,
#                                                  int basin_number, int saliency, int hlevel):
#
#     # define C data types of used variables
#     cdef int shape_col = quantised_array.shape[0]
#     cdef int shape_row = quantised_array.shape[1]
#     cdef int pc, pr, l
#     #cdef np.ndarray[DINT_t,ndim=2] pixel
#     cdef np.ndarray[DFLOAT_t, ndim=2] neighbours = np.full((1,2), np.nan)
#     cdef np.ndarray[DFLOAT_t, ndim=2] foot_hills = np.full((1,2), np.nan)
#     cdef np.ndarray[DFLOAT_t, ndim=2] basin = np.full((1,2), np.nan)
#     cdef np.ndarray[DINT_t, ndim = 2] neighbouring_pixels
#
#     # initialise neighbours with starting coordinates
#     neighbours[0]= [int(np.rint(center_col)),int(np.rint(center_row))]
#
#     # get length of neighbours
#     l = neighbours[:,0].size
#
#     #print "Bestimme Laenge. Laenge ist: %i" % l
#
#     while l > 0:
#         # get last element of the neighbours
#         if l > 1:
#             pc = neighbours[-1][0]
#             pr = neighbours[-1][1]
#
#             neighbours = neighbours[:-1]
#         elif l == 1 and not np.all(np.isnan(neighbours)):
#             pc = neighbours[0][0]
#             pr = neighbours[0][1]
#
#             neighbours = np.array([[np.nan,np.nan]])
#         elif l == 1 and np.all(np.isnan(neighbours)):
#             break
#         else:
#             break
#
#         #print "Koordinaten sind c=%i, r=%i" % (pc,pr)
#         # assign it to the current basin
#         if np.all(np.isnan(basin)):
#             basin[0] = np.array([pc, pr])
#         else:
#             basin = np.concatenate((basin,np.array([[pc,pr]])),axis=0)
#
#         #print "Koordinaten ans Becken angehaengt."
#         #print basin
#
#         #neighbouring_pixels = np.full((1,2),-1)
#         #print "Suche Nachbarn."
#         # get all neighbours of the current pixel
#         for i in np.arange(-1,2):
#             for j in np.arange(-1,2):
#                 if i == 0 and j == 0:
#                     continue
#                 else:
#                     if np.any(neighbouring_pixels) < 0 and len(neighbouring_pixels) == 1:
#                         neighbouring_pixels[0] = [pc+i,pr+j]
#                     else:
#                         neighbouring_pixels = np.concatenate((neighbouring_pixels,np.array([[pc+i,pr+j]])),axis=0)
#
#         #print "Die Nachbarn sind:"
#         #print neighbouring_pixels
#
#         # check if the current value of the pixel in the quantised array is above hlevel
#         # if true assign the pixel to the neighbours, if not assign it to the foot hills
#         #print "Ueberpruefe, ob Punkt ueber Schwellwert liegt."
#         if quantised_array[pc,pr] > hlevel:
#             #print "Haenge Nachbarn an."
#             for value in neighbouring_pixels:
#                 if not (value).__contains__(np.any(neighbours)):
#                     neighbours = np.concatenate((neighbours,np.array([value])),axis=0)
#             #print neighbours
#         else:
#             #print "Haenge Nachbarn an Bergfuss an."
#             for value in neighbouring_pixels:
#                 if not (value).__contains__(np.any(foot_hills)):
#                     if np.all(np.isnan(foot_hills)):
#                         foot_hills[0] = np.array([value[0],value[1]])
#                     else:
#                         foot_hills = np.concatenate((foot_hills,np.array([value])),axis=0)
#         #print "Bestimme wieder die Laenge."
#         l = neighbours[:,0].size
#         #print "Laenge = %i" % l
#
#     # fill basins with basin number
#     #print "Durchlaufe das Becken mit der Groesse %i, Schwellwert ist %i" % (basin[:,0].size, saliency)
#     if basin.shape[0] > saliency:
#         #print "Becken ist gross genug, Groesse %s,%s" % (basin.shape[0],basin.shape[1])
#         for i in xrange(len(basin)):
#             pixel = basin[i]
#             #print "Punkt %s" % pixel
#             pc = int(np.rint(pixel[0]))
#             pr = int(np.rint(pixel[1]))
#
#             #print "Weisse Punkt %i,%i die Beckennummer %i zu." % (pc,pr,basin_number)
#             basins[pc,pr] = basin_number
#     else:
#         #print "Becken ist zu klein. Groesse %s,%s" % (basin.shape[0],basin.shape[1])
#         print basin[0]
#         for i in xrange(len(basin)):
#             pixel = basin[i]
#             #print "Weisse Punkt %i,%i dem Bergfuss zu." % (pixel[0],pixel[1])
#             foot_hills = np.concatenate((foot_hills,np.array([pixel])),axis=0)
#
#     #print "Durchlaufe Bergfuesse."
#     for i in xrange(len(foot_hills)):
#         pixel = foot_hills[i]
#         pc = int(np.rint(pixel[0]))
#         pr = int(np.rint(pixel[1]))
#
#         #"Weisse dem Punkt %i,%i den Wert %i zu." % (pc,pr,-1)
#         basins[pc,pr] = -1
#     print "Gebe Becken zurueck."
#     return basins
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#             #print "Weisse Punkt %i,%i die Beckennummer %i zu." % (pc,pr,basin_number)
#             basins[pc,pr] = basin_number
#     else:
#         #print "Becken ist zu klein. Groesse %s,%s" % (basin.shape[0],basin.shape[1])
#         print basin[0]
#              ^
# ------------------------------------------------------------
#
# /home/lenk/.cache/ipython/cython/_cython_magic_bb2504555996456cbe6e34ff0a27ee06.pyx:111:14: Syntax error in simple statement list
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b9d8012456f6> in <module>
# ----> 1 get_ipython().run_cell_magic('cython', '', 'cimport numpy as np\nimport numpy as np\nDFLOAT = np.float\nDINT = np.int\nctypedef np.float_t DFLOAT_t\nctypedef np.int_t DINT_t\n\n\n#@cython.boundscheck(False)\ncpdef np.ndarray[DFLOAT_t, ndim=2] capture_basin(np.ndarray[DFLOAT_t, ndim=2] basins,\n                                                 np.ndarray[DFLOAT_t, ndim=2] quantised_array,\n                                                 float center_col, float center_row,\n                                                 int basin_number, int saliency, int hlevel):\n    \n    # define C data types of used variables\n    cdef int shape_col = quantised_array.shape[0]\n    cdef int shape_row = quantised_array.shape[1]\n    cdef int pc, pr, l\n    #cdef np.ndarray[DINT_t,ndim=2] pixel\n    cdef np.ndarray[DFLOAT_t, ndim=2] neighbours = np.full((1,2), np.nan)\n    cdef np.ndarray[DFLOAT_t, ndim=2] foot_hills = np.full((1,2), np.nan)\n    cdef np.ndarray[DFLOAT_t, ndim=2] basin = np.full((1,2), np.nan)\n    cdef np.ndarray[DINT_t, ndim = 2] neighbouring_pixels\n    \n    # initialise neighbours with starting coordinates\n    neighbours[0]= [int(np.rint(center_col)),int(np.rint(center_row))]\n    \n    # get length of neighbours\n    l = neighbours[:,0].size\n    \n    #print "Bestimme Laenge. Laenge ist: %i" % l\n    \n    while l > 0:\n        # get last element of the neighbours\n        if l > 1:\n            pc = neighbours[-1][0]\n            pr = neighbours[-1][1]\n        \n            neighbours = neighbours[:-1]\n        elif l == 1 and not np.all(np.isnan(neighbours)):\n            pc = neighbours[0][0]\n            pr = neighbours[0][1]           \n        \n            neighbours = np.array([[np.nan,np.nan]])\n        elif l == 1 and np.all(np.isnan(neighbours)):\n            break\n        else:\n            break\n        \n        #print "Koordinaten sind c=%i, r=%i" % (pc,pr)\n        # assign it to the current basin\n        if np.all(np.isnan(basin)):\n            basin[0] = np.array([pc, pr])\n        else:\n            basin = np.concatenate((basin,np.array([[pc,pr]])),axis=0)\n        \n        #print "Koordinaten ans Becken angehaengt."\n        #print basin\n        \n        #neighbouring_pixels = np.full((1,2),-1)\n        #print "Suche Nachbarn."\n        # get all neighbours of the current pixel\n        for i in np.arange(-1,2):\n            for j in np.arange(-1,2):\n                if i == 0 and j == 0:\n                    continue\n                else:\n                    if np.any(neighbouring_pixels) < 0 and len(neighbouring_pixels) == 1:\n                        neighbouring_pixels[0] = [pc+i,pr+j]\n                    else:\n                        neighbouring_pixels = np.concatenate((neighbouring_pixels,np.array([[pc+i,pr+j]])),axis=0)\n        \n        #print "Die Nachbarn sind:"\n        #print neighbouring_pixels\n        \n        # check if the current value of the pixel in the quantised array is above hlevel\n        # if true assign the pixel to the neighbours, if not assign it to the foot hills\n        #print "Ueberpruefe, ob Punkt ueber Schwellwert liegt."\n        if quantised_array[pc,pr] > hlevel:\n            #print "Haenge Nachbarn an."\n            for value in neighbouring_pixels:\n                if not (value).__contains__(np.any(neighbours)): \n                    neighbours = np.concatenate((neighbours,np.array([value])),axis=0)\n            #print neighbours\n        else:\n            #print "Haenge Nachbarn an Bergfuss an."\n            for value in neighbouring_pixels:\n                if not (value).__contains__(np.any(foot_hills)):\n                    if np.all(np.isnan(foot_hills)):\n                        foot_hills[0] = np.array([value[0],value[1]])\n                    else:\n                        foot_hills = np.concatenate((foot_hills,np.array([value])),axis=0)  \n        #print "Bestimme wieder die Laenge."            \n        l = neighbours[:,0]. ...
#
# /vols/satellite/home/lenk/anaconda3/envs/tracking/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# </vols/satellite/home/lenk/anaconda3/envs/tracking/lib/python3.7/site-packages/decorator.py:decorator-gen-128> in cython(self, line, cell)
#
# /vols/satellite/home/lenk/anaconda3/envs/tracking/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /vols/satellite/home/lenk/anaconda3/envs/tracking/lib/python3.7/site-packages/Cython/Build/IpythonMagic.py in cython(self, line, cell)
#     323         if need_cythonize:
#     324             extensions = self._cythonize(module_name, code, lib_dir, args, quiet=args.quiet)
# --> 325             assert len(extensions) == 1
#     326             extension = extensions[0]
#     327             self._code_cache[key] = module_name
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# Und nun die Funktion für die Ausführung des erweiterten Watershed-Algorithmus.

# %%
def find_basins(pixel_structure,centers,max_level,max_depth,basins,quantised_array,saliency):
    basin_number = 1
    
    for depth in range(max_depth+1):
        for level in range(1,max_level+1):
            hlevel = level - depth
            
            for center in centers[level]:
                if basins[int(np.rint(center[0])),
                          int(np.rint(center[1]))] < 0 :
                    basin = capture_basin(basins,quantised_array,center[0],center[1],basin_number,saliency,hlevel)
                    
                    b_idx = np.where(basin==basin_number)
                    basins[b_idx] = basin_number
                    
                    basin_number += 1
                else:
                    centers[level-1].append(center)
                    
    return basins

# %% [markdown]
# Nachdem wir jetzt alle Funktionen geladen haben, können wir das mal ausprobieren.
#
# Zuerst laden wir die Daten und glätten sie.

# %%
t = dt.datetime(2012,7,28,12,0)

s = msv.MSevi(time=t,chan_list=['IR_108','HRV'])
s.rad2bt()
s.rad2refl()

bt_smooth = ndi.gaussian_filter(s.bt['IR_108'],(1,0.5))
# Out:
# Region suggests use of hdf file
# /vols/satellite/home/lenk/anaconda3/envs/tracking/lib/python3.7/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)

# %%
fig, ax = plt.subplots(1,1,figsize=(14,14))
plot = ax.imshow(bt_smooth, vmin=210,vmax=300,cmap='gray_r')
fig.colorbar(plot)

# %% [markdown]
# Danach quantisieren wir das geglättete Feld.

# %%
bt_quant = quantise_field(bt_smooth,210,290,-10)

# %%
fig, ax = plt.subplots(1,1,figsize=(14,14))
plot = ax.imshow(bt_quant)
fig.colorbar(plot)

# %% [markdown]
# Im nächsten Schritt suchen wir uns die Maxima.

# %%
lmax = skmor.extrema.local_maxima(bt_quant)
lmax_labeled, nmax = ndi.label(lmax)

# %% [markdown]
# Danach speichern wir die Pixel im Bild mit einem Wert größer als Null in eine Datenstruktur.

# %%
pixel_structure = create_structure(bt_quant,np.max(bt_quant).astype("int"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4bfb46a78d03> in <module>
# ----> 1 pixel_structure = create_structure(bt_quant,np.max(bt_quant).astype("int"))
#
# <ipython-input-3-d3fc2b8f6d98> in create_structure(quantised_array, max_level)
#       1 def create_structure(quantised_array,max_level):
# ----> 2     pixels = {l:[] for l in xrange(int(max_level)+1)}
#       3
#       4     shape = quantised_array.shape
#       5
#
# NameError: name 'xrange' is not defined

# %% [markdown]
# Als nächstes wir uns die Schwerpunkte der Maximaobjekte und speichern sie ebenfalls in eine Struktur.

# %%
# find centers of the maxima
centers = {l:[] for l in np.arange(1,np.max(bt_quant).astype("int")+1)}

for label in xrange(1,nmax):

    cx,cy = ndi.measurements.center_of_mass(lmax,labels=lmax_labeled,index=label)

    level = bt_quant[int(np.rint(cx)),int(np.rint(cy))].astype("int")

    centers[level].append((cx,cy))

# %% [markdown]
# Nun können wir die Objekte finden. Dafür müssen wir noch eine Mindestgröße ("Salienz") und eine Maximaltiefe definieren.

# %%
basins = np.full_like(bt_smooth,-1)

saliency = 4
max_depth = 2

# %%
filled_basins = find_basins(pixel_structure,centers,np.max(bt_quant).astype("int"),max_depth,basins,bt_quant,saliency)
# Out:
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=4, r=789
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  3 788]
#  [  3 789]
#  [  3 790]
#  [  4 788]
#  [  4 790]
#  [  5 788]
#  [  5 789]
#  [  5 790]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [  4. 789.]
# Weisse Punkt 4,789 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=94, r=714
# Koordinaten ans Becken angehaengt.
# [[ 94. 714.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 93 713]
#  [ 93 714]
#  [ 93 715]
#  [ 94 713]
#  [ 94 715]
#  [ 95 713]
#  [ 95 714]
#  [ 95 715]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 94. 714.]
# Weisse Punkt 94,714 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=159, r=733
# Koordinaten ans Becken angehaengt.
# [[159. 733.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [158 732]
#  [158 733]
#  [158 734]
#  [159 732]
#  [159 734]
#  [160 732]
#  [160 733]
#  [160 734]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [159. 733.]
# Weisse Punkt 159,733 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=170, r=636
# Koordinaten ans Becken angehaengt.
# [[170. 636.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [169 635]
#  [169 636]
#  [169 637]
#  [170 635]
#  [170 637]
#  [171 635]
#  [171 636]
#  [171 637]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [170. 636.]
# Weisse Punkt 170,636 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=185, r=635
# Koordinaten ans Becken angehaengt.
# [[185. 635.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [184 634]
#  [184 635]
#  [184 636]
#  [185 634]
#  [185 636]
#  [186 634]
#  [186 635]
#  [186 636]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [185. 635.]
# Weisse Punkt 185,635 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=200, r=743
# Koordinaten ans Becken angehaengt.
# [[200. 743.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [199 742]
#  [199 743]
#  [199 744]
#  [200 742]
#  [200 744]
#  [201 742]
#  [201 743]
#  [201 744]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [200. 743.]
# Weisse Punkt 200,743 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=200, r=798
# Koordinaten ans Becken angehaengt.
# [[200. 798.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [199 797]
#  [199 798]
#  [199 799]
#  [200 797]
#  [200 799]
#  [201 797]
#  [201 798]
#  [201 799]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [200. 798.]
# Weisse Punkt 200,798 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=261, r=226
# Koordinaten ans Becken angehaengt.
# [[261. 226.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [260 225]
#  [260 226]
#  [260 227]
#  [261 225]
#  [261 227]
#  [262 225]
#  [262 226]
#  [262 227]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [261. 226.]
# Weisse Punkt 261,226 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=273, r=512
# Koordinaten ans Becken angehaengt.
# [[273. 512.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [272 511]
#  [272 512]
#  [272 513]
#  [273 511]
#  [273 513]
#  [274 511]
#  [274 512]
#  [274 513]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [273. 512.]
# Weisse Punkt 273,512 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=275, r=494
# Koordinaten ans Becken angehaengt.
# [[275. 494.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [274 493]
#  [274 494]
#  [274 495]
#  [275 493]
#  [275 495]
#  [276 493]
#  [276 494]
#  [276 495]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [275. 494.]
# Weisse Punkt 275,494 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=304, r=30
# Koordinaten ans Becken angehaengt.
# [[304.  30.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [303  29]
#  [303  30]
#  [303  31]
#  [304  29]
#  [304  31]
#  [305  29]
#  [305  30]
#  [305  31]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [304.  30.]
# Weisse Punkt 304,30 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=342, r=314
# Koordinaten ans Becken angehaengt.
# [[342. 314.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [341 313]
#  [341 314]
#  [341 315]
#  [342 313]
#  [342 315]
#  [343 313]
#  [343 314]
#  [343 315]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [342. 314.]
# Weisse Punkt 342,314 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=353, r=90
# Koordinaten ans Becken angehaengt.
# [[353.  90.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [352  89]
#  [352  90]
#  [352  91]
#  [353  89]
#  [353  91]
#  [354  89]
#  [354  90]
#  [354  91]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [353.  90.]
# Weisse Punkt 353,90 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=356, r=520
# Koordinaten ans Becken angehaengt.
# [[356. 520.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [355 519]
#  [355 520]
#  [355 521]
#  [356 519]
#  [356 521]
#  [357 519]
#  [357 520]
#  [357 521]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [356. 520.]
# Weisse Punkt 356,520 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=373, r=516
# Koordinaten ans Becken angehaengt.
# [[373. 516.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [372 515]
#  [372 516]
#  [372 517]
#  [373 515]
#  [373 517]
#  [374 515]
#  [374 516]
#  [374 517]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [373. 516.]
# Weisse Punkt 373,516 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=378, r=536
# Koordinaten ans Becken angehaengt.
# [[378. 536.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [377 535]
#  [377 536]
#  [377 537]
#  [378 535]
#  [378 537]
#  [379 535]
#  [379 536]
#  [379 537]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [378. 536.]
# Weisse Punkt 378,536 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=452, r=398
# Koordinaten ans Becken angehaengt.
# [[452. 398.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [451 397]
#  [451 398]
#  [451 399]
#  [452 397]
#  [452 399]
#  [453 397]
#  [453 398]
#  [453 399]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [452. 398.]
# Weisse Punkt 452,398 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=499, r=361
# Koordinaten ans Becken angehaengt.
# [[499. 361.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [498 360]
#  [498 361]
#  [498 362]
#  [499 360]
#  [499 362]
#  [500 360]
#  [500 361]
#  [500 362]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [499. 361.]
# Weisse Punkt 499,361 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=525, r=383
# Koordinaten ans Becken angehaengt.
# [[525. 383.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [524 382]
#  [524 383]
#  [524 384]
#  [525 382]
#  [525 384]
#  [526 382]
#  [526 383]
#  [526 384]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [525. 383.]
# Weisse Punkt 525,383 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=10, r=349
# Koordinaten ans Becken angehaengt.
# [[ 10. 349.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  9 348]
#  [  9 349]
#  [  9 350]
#  [ 10 348]
#  [ 10 350]
#  [ 11 348]
#  [ 11 349]
#  [ 11 350]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 10. 349.]
# Weisse Punkt 10,349 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=10, r=720
# Koordinaten ans Becken angehaengt.
# [[ 10. 720.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  9 719]
#  [  9 720]
#  [  9 721]
#  [ 10 719]
#  [ 10 721]
#  [ 11 719]
#  [ 11 720]
#  [ 11 721]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 10. 720.]
# Weisse Punkt 10,720 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=24, r=366
# Koordinaten ans Becken angehaengt.
# [[ 24. 366.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 23 365]
#  [ 23 366]
#  [ 23 367]
#  [ 24 365]
#  [ 24 367]
#  [ 25 365]
#  [ 25 366]
#  [ 25 367]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 24. 366.]
# Weisse Punkt 24,366 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=34, r=798
# Koordinaten ans Becken angehaengt.
# [[ 34. 798.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 33 797]
#  [ 33 798]
#  [ 33 799]
#  [ 34 797]
#  [ 34 799]
#  [ 35 797]
#  [ 35 798]
#  [ 35 799]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 34. 798.]
# Weisse Punkt 34,798 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=68, r=339
# Koordinaten ans Becken angehaengt.
# [[ 68. 339.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 67 338]
#  [ 67 339]
#  [ 67 340]
#  [ 68 338]
#  [ 68 340]
#  [ 69 338]
#  [ 69 339]
#  [ 69 340]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 68. 339.]
# Weisse Punkt 68,339 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=126, r=710
# Koordinaten ans Becken angehaengt.
# [[126. 710.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [125 709]
#  [125 710]
#  [125 711]
#  [126 709]
#  [126 711]
#  [127 709]
#  [127 710]
#  [127 711]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [126. 710.]
# Weisse Punkt 126,710 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=137, r=283
# Koordinaten ans Becken angehaengt.
# [[137. 283.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [136 282]
#  [136 283]
#  [136 284]
#  [137 282]
#  [137 284]
#  [138 282]
#  [138 283]
#  [138 284]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [137. 283.]
# Weisse Punkt 137,283 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=154, r=216
# Koordinaten ans Becken angehaengt.
# [[154. 216.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [153 215]
#  [153 216]
#  [153 217]
#  [154 215]
#  [154 217]
#  [155 215]
#  [155 216]
#  [155 217]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [154. 216.]
# Weisse Punkt 154,216 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=159, r=108
# Koordinaten ans Becken angehaengt.
# [[159. 108.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [158 107]
#  [158 108]
#  [158 109]
#  [159 107]
#  [159 109]
#  [160 107]
#  [160 108]
#  [160 109]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [159. 108.]
# Weisse Punkt 159,108 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=177, r=700
# Koordinaten ans Becken angehaengt.
# [[177. 700.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [176 699]
#  [176 700]
#  [176 701]
#  [177 699]
#  [177 701]
#  [178 699]
#  [178 700]
#  [178 701]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [177. 700.]
# Weisse Punkt 177,700 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=180, r=379
# Koordinaten ans Becken angehaengt.
# [[180. 379.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [179 378]
#  [179 379]
#  [179 380]
#  [180 378]
#  [180 380]
#  [181 378]
#  [181 379]
#  [181 380]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [180. 379.]
# Weisse Punkt 180,379 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=202, r=136
# Koordinaten ans Becken angehaengt.
# [[202. 136.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [201 135]
#  [201 136]
#  [201 137]
#  [202 135]
#  [202 137]
#  [203 135]
#  [203 136]
#  [203 137]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [202. 136.]
# Weisse Punkt 202,136 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=229, r=409
# Koordinaten ans Becken angehaengt.
# [[229. 409.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [228 408]
#  [228 409]
#  [228 410]
#  [229 408]
#  [229 410]
#  [230 408]
#  [230 409]
#  [230 410]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [229. 409.]
# Weisse Punkt 229,409 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=270, r=318
# Koordinaten ans Becken angehaengt.
# [[270. 318.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [269 317]
#  [269 318]
#  [269 319]
#  [270 317]
#  [270 319]
#  [271 317]
#  [271 318]
#  [271 319]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [270. 318.]
# Weisse Punkt 270,318 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=279, r=459
# Koordinaten ans Becken angehaengt.
# [[279. 459.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [278 458]
#  [278 459]
#  [278 460]
#  [279 458]
#  [279 460]
#  [280 458]
#  [280 459]
#  [280 460]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [279. 459.]
# Weisse Punkt 279,459 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=309, r=231
# Koordinaten ans Becken angehaengt.
# [[309. 231.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [308 230]
#  [308 231]
#  [308 232]
#  [309 230]
#  [309 232]
#  [310 230]
#  [310 231]
#  [310 232]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [309. 231.]
# Weisse Punkt 309,231 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=327, r=126
# Koordinaten ans Becken angehaengt.
# [[327. 126.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [326 125]
#  [326 126]
#  [326 127]
#  [327 125]
#  [327 127]
#  [328 125]
#  [328 126]
#  [328 127]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [327. 126.]
# Weisse Punkt 327,126 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=329, r=192
# Koordinaten ans Becken angehaengt.
# [[329. 192.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [328 191]
#  [328 192]
#  [328 193]
#  [329 191]
#  [329 193]
#  [330 191]
#  [330 192]
#  [330 193]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [329. 192.]
# Weisse Punkt 329,192 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=340, r=567
# Koordinaten ans Becken angehaengt.
# [[340. 567.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [339 566]
#  [339 567]
#  [339 568]
#  [340 566]
#  [340 568]
#  [341 566]
#  [341 567]
#  [341 568]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [340. 567.]
# Weisse Punkt 340,567 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=346, r=543
# Koordinaten ans Becken angehaengt.
# [[346. 543.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [345 542]
#  [345 543]
#  [345 544]
#  [346 542]
#  [346 544]
#  [347 542]
#  [347 543]
#  [347 544]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [346. 543.]
# Weisse Punkt 346,543 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=347, r=558
# Koordinaten ans Becken angehaengt.
# [[347. 558.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [346 557]
#  [346 558]
#  [346 559]
#  [347 557]
#  [347 559]
#  [348 557]
#  [348 558]
#  [348 559]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [347. 558.]
# Weisse Punkt 347,558 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=351, r=478
# Koordinaten ans Becken angehaengt.
# [[351. 478.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [350 477]
#  [350 478]
#  [350 479]
#  [351 477]
#  [351 479]
#  [352 477]
#  [352 478]
#  [352 479]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [351. 478.]
# Weisse Punkt 351,478 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=390, r=232
# Koordinaten ans Becken angehaengt.
# [[390. 232.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [389 231]
#  [389 232]
#  [389 233]
#  [390 231]
#  [390 233]
#  [391 231]
#  [391 232]
#  [391 233]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [390. 232.]
# Weisse Punkt 390,232 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=404, r=42
# Koordinaten ans Becken angehaengt.
# [[404.  42.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [403  41]
#  [403  42]
#  [403  43]
#  [404  41]
#  [404  43]
#  [405  41]
#  [405  42]
#  [405  43]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [404.  42.]
# Weisse Punkt 404,42 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=426, r=408
# Koordinaten ans Becken angehaengt.
# [[426. 408.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [425 407]
#  [425 408]
#  [425 409]
#  [426 407]
#  [426 409]
#  [427 407]
#  [427 408]
#  [427 409]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [426. 408.]
# Weisse Punkt 426,408 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=421, r=317
# Koordinaten ans Becken angehaengt.
# [[421. 317.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [420 316]
#  [420 317]
#  [420 318]
#  [421 316]
#  [421 318]
#  [422 316]
#  [422 317]
#  [422 318]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [421. 317.]
# Weisse Punkt 421,317 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=425, r=305
# Koordinaten ans Becken angehaengt.
# [[425. 305.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [424 304]
#  [424 305]
#  [424 306]
#  [425 304]
#  [425 306]
#  [426 304]
#  [426 305]
#  [426 306]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [425. 305.]
# Weisse Punkt 425,305 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=437, r=387
# Koordinaten ans Becken angehaengt.
# [[437. 387.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [436 386]
#  [436 387]
#  [436 388]
#  [437 386]
#  [437 388]
#  [438 386]
#  [438 387]
#  [438 388]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [437. 387.]
# Weisse Punkt 437,387 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=438, r=286
# Koordinaten ans Becken angehaengt.
# [[438. 286.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [437 285]
#  [437 286]
#  [437 287]
#  [438 285]
#  [438 287]
#  [439 285]
#  [439 286]
#  [439 287]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [438. 286.]
# Weisse Punkt 438,286 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=443, r=330
# Koordinaten ans Becken angehaengt.
# [[443. 330.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [442 329]
#  [442 330]
#  [442 331]
#  [443 329]
#  [443 331]
#  [444 329]
#  [444 330]
#  [444 331]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [443. 330.]
# Weisse Punkt 443,330 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=445, r=369
# Koordinaten ans Becken angehaengt.
# [[445. 369.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [444 368]
#  [444 369]
#  [444 370]
#  [445 368]
#  [445 370]
#  [446 368]
#  [446 369]
#  [446 370]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [445. 369.]
# Weisse Punkt 445,369 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=448, r=379
# Koordinaten ans Becken angehaengt.
# [[448. 379.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [447 378]
#  [447 379]
#  [447 380]
#  [448 378]
#  [448 380]
#  [449 378]
#  [449 379]
#  [449 380]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [448. 379.]
# Weisse Punkt 448,379 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=450, r=353
# Koordinaten ans Becken angehaengt.
# [[450. 353.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [449 352]
#  [449 353]
#  [449 354]
#  [450 352]
#  [450 354]
#  [451 352]
#  [451 353]
#  [451 354]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [450. 353.]
# Weisse Punkt 450,353 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=453, r=453
# Koordinaten ans Becken angehaengt.
# [[453. 453.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [452 452]
#  [452 453]
#  [452 454]
#  [453 452]
#  [453 454]
#  [454 452]
#  [454 453]
#  [454 454]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [453. 453.]
# Weisse Punkt 453,453 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=458, r=341
# Koordinaten ans Becken angehaengt.
# [[458. 341.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [457 340]
#  [457 341]
#  [457 342]
#  [458 340]
#  [458 342]
#  [459 340]
#  [459 341]
#  [459 342]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [458. 341.]
# Weisse Punkt 458,341 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=53, r=722
# Koordinaten ans Becken angehaengt.
# [[ 53. 722.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 52 721]
#  [ 52 722]
#  [ 52 723]
#  [ 53 721]
#  [ 53 723]
#  [ 54 721]
#  [ 54 722]
#  [ 54 723]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 53. 722.]
# Weisse Punkt 53,722 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=70, r=573
# Koordinaten ans Becken angehaengt.
# [[ 70. 573.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 69 572]
#  [ 69 573]
#  [ 69 574]
#  [ 70 572]
#  [ 70 574]
#  [ 71 572]
#  [ 71 573]
#  [ 71 574]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 70. 573.]
# Weisse Punkt 70,573 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=81, r=575
# Koordinaten ans Becken angehaengt.
# [[ 81. 575.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 80 574]
#  [ 80 575]
#  [ 80 576]
#  [ 81 574]
#  [ 81 576]
#  [ 82 574]
#  [ 82 575]
#  [ 82 576]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 81. 575.]
# Weisse Punkt 81,575 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=92, r=290
# Koordinaten ans Becken angehaengt.
# [[ 92. 290.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 91 289]
#  [ 91 290]
#  [ 91 291]
#  [ 92 289]
#  [ 92 291]
#  [ 93 289]
#  [ 93 290]
#  [ 93 291]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 92. 290.]
# Weisse Punkt 92,290 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=93, r=217
# Koordinaten ans Becken angehaengt.
# [[ 93. 217.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 92 216]
#  [ 92 217]
#  [ 92 218]
#  [ 93 216]
#  [ 93 218]
#  [ 94 216]
#  [ 94 217]
#  [ 94 218]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 93. 217.]
# Weisse Punkt 93,217 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=99, r=251
# Koordinaten ans Becken angehaengt.
# [[ 99. 251.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 98 250]
#  [ 98 251]
#  [ 98 252]
#  [ 99 250]
#  [ 99 252]
#  [100 250]
#  [100 251]
#  [100 252]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 99. 251.]
# Weisse Punkt 99,251 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=110, r=266
# Koordinaten ans Becken angehaengt.
# [[110. 266.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [109 265]
#  [109 266]
#  [109 267]
#  [110 265]
#  [110 267]
#  [111 265]
#  [111 266]
#  [111 267]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [110. 266.]
# Weisse Punkt 110,266 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=127, r=653
# Koordinaten ans Becken angehaengt.
# [[127. 653.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [126 652]
#  [126 653]
#  [126 654]
#  [127 652]
#  [127 654]
#  [128 652]
#  [128 653]
#  [128 654]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [127. 653.]
# Weisse Punkt 127,653 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=133, r=638
# Koordinaten ans Becken angehaengt.
# [[133. 638.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [132 637]
#  [132 638]
#  [132 639]
#  [133 637]
#  [133 639]
#  [134 637]
#  [134 638]
#  [134 639]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [133. 638.]
# Weisse Punkt 133,638 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=166, r=267
# Koordinaten ans Becken angehaengt.
# [[166. 267.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [165 266]
#  [165 267]
#  [165 268]
#  [166 266]
#  [166 268]
#  [167 266]
#  [167 267]
#  [167 268]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [166. 267.]
# Weisse Punkt 166,267 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=176, r=240
# Koordinaten ans Becken angehaengt.
# [[176. 240.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [175 239]
#  [175 240]
#  [175 241]
#  [176 239]
#  [176 241]
#  [177 239]
#  [177 240]
#  [177 241]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [176. 240.]
# Weisse Punkt 176,240 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=222, r=18
# Koordinaten ans Becken angehaengt.
# [[222.  18.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [221  17]
#  [221  18]
#  [221  19]
#  [222  17]
#  [222  19]
#  [223  17]
#  [223  18]
#  [223  19]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [222.  18.]
# Weisse Punkt 222,18 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=236, r=52
# Koordinaten ans Becken angehaengt.
# [[236.  52.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [235  51]
#  [235  52]
#  [235  53]
#  [236  51]
#  [236  53]
#  [237  51]
#  [237  52]
#  [237  53]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [236.  52.]
# Weisse Punkt 236,52 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=238, r=285
# Koordinaten ans Becken angehaengt.
# [[238. 285.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [237 284]
#  [237 285]
#  [237 286]
#  [238 284]
#  [238 286]
#  [239 284]
#  [239 285]
#  [239 286]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [238. 285.]
# Weisse Punkt 238,285 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=242, r=10
# Koordinaten ans Becken angehaengt.
# [[242.  10.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [241   9]
#  [241  10]
#  [241  11]
#  [242   9]
#  [242  11]
#  [243   9]
#  [243  10]
#  [243  11]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [242.  10.]
# Weisse Punkt 242,10 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=244, r=318
# Koordinaten ans Becken angehaengt.
# [[244. 318.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [243 317]
#  [243 318]
#  [243 319]
#  [244 317]
#  [244 319]
#  [245 317]
#  [245 318]
#  [245 319]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [244. 318.]
# Weisse Punkt 244,318 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=288, r=326
# Koordinaten ans Becken angehaengt.
# [[288. 326.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [287 325]
#  [287 326]
#  [287 327]
#  [288 325]
#  [288 327]
#  [289 325]
#  [289 326]
#  [289 327]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [288. 326.]
# Weisse Punkt 288,326 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=370, r=172
# Koordinaten ans Becken angehaengt.
# [[370. 172.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [369 171]
#  [369 172]
#  [369 173]
#  [370 171]
#  [370 173]
#  [371 171]
#  [371 172]
#  [371 173]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [370. 172.]
# Weisse Punkt 370,172 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=378, r=151
# Koordinaten ans Becken angehaengt.
# [[378. 151.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [377 150]
#  [377 151]
#  [377 152]
#  [378 150]
#  [378 152]
#  [379 150]
#  [379 151]
#  [379 152]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [378. 151.]
# Weisse Punkt 378,151 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=399, r=64
# Koordinaten ans Becken angehaengt.
# [[399.  64.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [398  63]
#  [398  64]
#  [398  65]
#  [399  63]
#  [399  65]
#  [400  63]
#  [400  64]
#  [400  65]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [399.  64.]
# Weisse Punkt 399,64 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=429, r=348
# Koordinaten ans Becken angehaengt.
# [[429. 348.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [428 347]
#  [428 348]
#  [428 349]
#  [429 347]
#  [429 349]
#  [430 347]
#  [430 348]
#  [430 349]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [429. 348.]
# Weisse Punkt 429,348 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=443, r=310
# Koordinaten ans Becken angehaengt.
# [[443. 310.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [442 309]
#  [442 310]
#  [442 311]
#  [443 309]
#  [443 311]
#  [444 309]
#  [444 310]
#  [444 311]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [443. 310.]
# Weisse Punkt 443,310 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=460, r=283
# Koordinaten ans Becken angehaengt.
# [[460. 283.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [459 282]
#  [459 283]
#  [459 284]
#  [460 282]
#  [460 284]
#  [461 282]
#  [461 283]
#  [461 284]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [460. 283.]
# Weisse Punkt 460,283 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=459, r=302
# Koordinaten ans Becken angehaengt.
# [[459. 302.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [458 301]
#  [458 302]
#  [458 303]
#  [459 301]
#  [459 303]
#  [460 301]
#  [460 302]
#  [460 303]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [459. 302.]
# Weisse Punkt 459,302 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=474, r=317
# Koordinaten ans Becken angehaengt.
# [[474. 317.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [473 316]
#  [473 317]
#  [473 318]
#  [474 316]
#  [474 318]
#  [475 316]
#  [475 317]
#  [475 318]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [474. 317.]
# Weisse Punkt 474,317 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=480, r=373
# Koordinaten ans Becken angehaengt.
# [[480. 373.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [479 372]
#  [479 373]
#  [479 374]
#  [480 372]
#  [480 374]
#  [481 372]
#  [481 373]
#  [481 374]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [480. 373.]
# Weisse Punkt 480,373 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=479, r=260
# Koordinaten ans Becken angehaengt.
# [[479. 260.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [478 259]
#  [478 260]
#  [478 261]
#  [479 259]
#  [479 261]
#  [480 259]
#  [480 260]
#  [480 261]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [479. 260.]
# Weisse Punkt 479,260 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=485, r=406
# Koordinaten ans Becken angehaengt.
# [[485. 406.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [484 405]
#  [484 406]
#  [484 407]
#  [485 405]
#  [485 407]
#  [486 405]
#  [486 406]
#  [486 407]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [485. 406.]
# Weisse Punkt 485,406 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=501, r=389
# Koordinaten ans Becken angehaengt.
# [[501. 389.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [500 388]
#  [500 389]
#  [500 390]
#  [501 388]
#  [501 390]
#  [502 388]
#  [502 389]
#  [502 390]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [501. 389.]
# Weisse Punkt 501,389 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=32, r=251
# Koordinaten ans Becken angehaengt.
# [[ 32. 251.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 31 250]
#  [ 31 251]
#  [ 31 252]
#  [ 32 250]
#  [ 32 252]
#  [ 33 250]
#  [ 33 251]
#  [ 33 252]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 32. 251.]
# Weisse Punkt 32,251 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=43, r=157
# Koordinaten ans Becken angehaengt.
# [[ 43. 157.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 42 156]
#  [ 42 157]
#  [ 42 158]
#  [ 43 156]
#  [ 43 158]
#  [ 44 156]
#  [ 44 157]
#  [ 44 158]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 43. 157.]
# Weisse Punkt 43,157 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=51, r=181
# Koordinaten ans Becken angehaengt.
# [[ 51. 181.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 50 180]
#  [ 50 181]
#  [ 50 182]
#  [ 51 180]
#  [ 51 182]
#  [ 52 180]
#  [ 52 181]
#  [ 52 182]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 51. 181.]
# Weisse Punkt 51,181 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=57, r=219
# Koordinaten ans Becken angehaengt.
# [[ 57. 219.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 56 218]
#  [ 56 219]
#  [ 56 220]
#  [ 57 218]
#  [ 57 220]
#  [ 58 218]
#  [ 58 219]
#  [ 58 220]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 1
# Durchlaufe das Becken mit der Groesse 1, Schwellwert ist 4
# Becken ist zu klein. Groesse 1,2
# [ 57. 219.]
# Weisse Punkt 57,219 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=65, r=165
# Koordinaten ans Becken angehaengt.
# [[ 65. 165.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 64 164]
#  [ 64 165]
#  [ 64 166]
#  [ 65 164]
#  [ 65 166]
#  [ 66 164]
#  [ 66 165]
#  [ 66 166]]
# ...
# Becken ist zu klein. Groesse 1,2
# [244. 576.]
# Weisse Punkt 244,576 dem Bergfuss zu.
# Durchlaufe Bergfuesse.
# Gebe Becken zurueck.
# Bestimme Laenge. Laenge ist: 1
# Koordinaten sind c=4, r=789
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  3 788]
#  [  3 789]
#  [  3 790]
#  [  4 788]
#  [  4 790]
#  [  5 788]
#  [  5 789]
#  [  5 790]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [  5. 790.]]
# Bestimme wieder die Laenge.
# Laenge = 10
# Koordinaten sind c=5, r=790
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  4 789]
#  [  4 790]
#  [  4 791]
#  [  5 789]
#  [  5 791]
#  [  6 789]
#  [  6 790]
#  [  6 791]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [  6. 791.]]
# Bestimme wieder die Laenge.
# Laenge = 18
# Koordinaten sind c=6, r=791
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  5 790]
#  [  5 791]
#  [  5 792]
#  [  6 790]
#  [  6 792]
#  [  7 790]
#  [  7 791]
#  [  7 792]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [  7. 792.]]
# Bestimme wieder die Laenge.
# Laenge = 26
# Koordinaten sind c=7, r=792
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  6 791]
#  [  6 792]
#  [  6 793]
#  [  7 791]
#  [  7 793]
#  [  8 791]
#  [  8 792]
#  [  8 793]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [  8. 793.]]
# Bestimme wieder die Laenge.
# Laenge = 34
# Koordinaten sind c=8, r=793
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  7 792]
#  [  7 793]
#  [  7 794]
#  [  8 792]
#  [  8 794]
#  [  9 792]
#  [  9 793]
#  [  9 794]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [  9. 794.]]
# Bestimme wieder die Laenge.
# Laenge = 42
# Koordinaten sind c=9, r=794
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  8 793]
#  [  8 794]
#  [  8 795]
#  [  9 793]
#  [  9 795]
#  [ 10 793]
#  [ 10 794]
#  [ 10 795]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [ -1.  -1.]
#  [  8. 793.]
#  [  8. 794.]
#  [  8. 795.]
#  [  9. 793.]
#  [  9. 795.]
#  [ 10. 793.]
#  [ 10. 794.]
#  [ 10. 795.]]
# Bestimme wieder die Laenge.
# Laenge = 50
# Koordinaten sind c=10, r=795
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [  9 794]
#  [  9 795]
#  [  9 796]
#  [ 10 794]
#  [ 10 796]
#  [ 11 794]
#  [ 11 795]
#  [ 11 796]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [ -1.  -1.]
#  [  8. 793.]
#  [  8. 794.]
#  [  8. 795.]
#  [  9. 793.]
#  [  9. 795.]
#  [ 10. 793.]
#  [ 10. 794.]
#  [ -1.  -1.]
#  [  9. 794.]
#  [  9. 795.]
#  [  9. 796.]
#  [ 10. 794.]
#  [ 10. 796.]
#  [ 11. 794.]
#  [ 11. 795.]
#  [ 11. 796.]]
# Bestimme wieder die Laenge.
# Laenge = 58
# Koordinaten sind c=11, r=796
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 10 795]
#  [ 10 796]
#  [ 10 797]
#  [ 11 795]
#  [ 11 797]
#  [ 12 795]
#  [ 12 796]
#  [ 12 797]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [ -1.  -1.]
#  [  8. 793.]
#  [  8. 794.]
#  [  8. 795.]
#  [  9. 793.]
#  [  9. 795.]
#  [ 10. 793.]
#  [ 10. 794.]
#  [ -1.  -1.]
#  [  9. 794.]
#  [  9. 795.]
#  [  9. 796.]
#  [ 10. 794.]
#  [ 10. 796.]
#  [ 11. 794.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 795.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 11. 795.]
#  [ 11. 797.]
#  [ 12. 795.]
#  [ 12. 796.]
#  [ 12. 797.]]
# Bestimme wieder die Laenge.
# Laenge = 66
# Koordinaten sind c=12, r=797
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 11 796]
#  [ 11 797]
#  [ 11 798]
#  [ 12 796]
#  [ 12 798]
#  [ 13 796]
#  [ 13 797]
#  [ 13 798]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 65
# Koordinaten sind c=12, r=796
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 11 795]
#  [ 11 796]
#  [ 11 797]
#  [ 12 795]
#  [ 12 797]
#  [ 13 795]
#  [ 13 796]
#  [ 13 797]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 64
# Koordinaten sind c=12, r=795
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 11 794]
#  [ 11 795]
#  [ 11 796]
#  [ 12 794]
#  [ 12 796]
#  [ 13 794]
#  [ 13 795]
#  [ 13 796]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 63
# Koordinaten sind c=11, r=797
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 10 796]
#  [ 10 797]
#  [ 10 798]
#  [ 11 796]
#  [ 11 798]
#  [ 12 796]
#  [ 12 797]
#  [ 12 798]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [ -1.  -1.]
#  [  8. 793.]
#  [  8. 794.]
#  [  8. 795.]
#  [  9. 793.]
#  [  9. 795.]
#  [ 10. 793.]
#  [ 10. 794.]
#  [ -1.  -1.]
#  [  9. 794.]
#  [  9. 795.]
#  [  9. 796.]
#  [ 10. 794.]
#  [ 10. 796.]
#  [ 11. 794.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 795.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 10. 798.]
#  [ 11. 796.]
#  [ 11. 798.]
#  [ 12. 796.]
#  [ 12. 797.]
#  [ 12. 798.]]
# Bestimme wieder die Laenge.
# Laenge = 71
# Koordinaten sind c=12, r=798
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]
#  [ 12. 798.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 11 797]
#  [ 11 798]
#  [ 11 799]
#  [ 12 797]
#  [ 12 799]
#  [ 13 797]
#  [ 13 798]
#  [ 13 799]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [ -1.  -1.]
#  [  8. 793.]
#  [  8. 794.]
#  [  8. 795.]
#  [  9. 793.]
#  [  9. 795.]
#  [ 10. 793.]
#  [ 10. 794.]
#  [ -1.  -1.]
#  [  9. 794.]
#  [  9. 795.]
#  [  9. 796.]
#  [ 10. 794.]
#  [ 10. 796.]
#  [ 11. 794.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 795.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 10. 798.]
#  [ 11. 796.]
#  [ 11. 798.]
#  [ 12. 796.]
#  [ 12. 797.]
#  [ -1.  -1.]
#  [ 11. 797.]
#  [ 11. 798.]
#  [ 11. 799.]
#  [ 12. 797.]
#  [ 12. 799.]
#  [ 13. 797.]
#  [ 13. 798.]
#  [ 13. 799.]]
# Bestimme wieder die Laenge.
# Laenge = 79
# Koordinaten sind c=13, r=799
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]
#  [ 12. 798.]
#  [ 13. 799.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 12 798]
#  [ 12 799]
#  [ 12 800]
#  [ 13 798]
#  [ 13 800]
#  [ 14 798]
#  [ 14 799]
#  [ 14 800]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 78
# Koordinaten sind c=13, r=798
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]
#  [ 12. 798.]
#  [ 13. 799.]
#  [ 13. 798.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 12 797]
#  [ 12 798]
#  [ 12 799]
#  [ 13 797]
#  [ 13 799]
#  [ 14 797]
#  [ 14 798]
#  [ 14 799]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 77
# Koordinaten sind c=13, r=797
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]
#  [ 12. 798.]
#  [ 13. 799.]
#  [ 13. 798.]
#  [ 13. 797.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 12 796]
#  [ 12 797]
#  [ 12 798]
#  [ 13 796]
#  [ 13 798]
#  [ 14 796]
#  [ 14 797]
#  [ 14 798]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an Bergfuss an.
# Bestimme wieder die Laenge.
# Laenge = 76
# Koordinaten sind c=12, r=799
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]
#  [ 12. 798.]
#  [ 13. 799.]
#  [ 13. 798.]
#  [ 13. 797.]
#  [ 12. 799.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 11 798]
#  [ 11 799]
#  [ 11 800]
#  [ 12 798]
#  [ 12 800]
#  [ 13 798]
#  [ 13 799]
#  [ 13 800]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# Haenge Nachbarn an.
# [[ nan  nan]
#  [ -1.  -1.]
#  [  3. 788.]
#  [  3. 789.]
#  [  3. 790.]
#  [  4. 788.]
#  [  4. 790.]
#  [  5. 788.]
#  [  5. 789.]
#  [ -1.  -1.]
#  [  4. 789.]
#  [  4. 790.]
#  [  4. 791.]
#  [  5. 789.]
#  [  5. 791.]
#  [  6. 789.]
#  [  6. 790.]
#  [ -1.  -1.]
#  [  5. 790.]
#  [  5. 791.]
#  [  5. 792.]
#  [  6. 790.]
#  [  6. 792.]
#  [  7. 790.]
#  [  7. 791.]
#  [ -1.  -1.]
#  [  6. 791.]
#  [  6. 792.]
#  [  6. 793.]
#  [  7. 791.]
#  [  7. 793.]
#  [  8. 791.]
#  [  8. 792.]
#  [ -1.  -1.]
#  [  7. 792.]
#  [  7. 793.]
#  [  7. 794.]
#  [  8. 792.]
#  [  8. 794.]
#  [  9. 792.]
#  [  9. 793.]
#  [ -1.  -1.]
#  [  8. 793.]
#  [  8. 794.]
#  [  8. 795.]
#  [  9. 793.]
#  [  9. 795.]
#  [ 10. 793.]
#  [ 10. 794.]
#  [ -1.  -1.]
#  [  9. 794.]
#  [  9. 795.]
#  [  9. 796.]
#  [ 10. 794.]
#  [ 10. 796.]
#  [ 11. 794.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 795.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 11. 795.]
#  [ -1.  -1.]
#  [ 10. 796.]
#  [ 10. 797.]
#  [ 10. 798.]
#  [ 11. 796.]
#  [ 11. 798.]
#  [ 12. 796.]
#  [ 12. 797.]
#  [ -1.  -1.]
#  [ 11. 797.]
#  [ 11. 798.]
#  [ 11. 799.]
#  [ 12. 797.]
#  [ -1.  -1.]
#  [ 11. 798.]
#  [ 11. 799.]
#  [ 11. 800.]
#  [ 12. 798.]
#  [ 12. 800.]
#  [ 13. 798.]
#  [ 13. 799.]
#  [ 13. 800.]]
# Bestimme wieder die Laenge.
# Laenge = 84
# Koordinaten sind c=13, r=800
# Koordinaten ans Becken angehaengt.
# [[  4. 789.]
#  [  5. 790.]
#  [  6. 791.]
#  [  7. 792.]
#  [  8. 793.]
#  [  9. 794.]
#  [ 10. 795.]
#  [ 11. 796.]
#  [ 12. 797.]
#  [ 12. 796.]
#  [ 12. 795.]
#  [ 11. 797.]
#  [ 12. 798.]
#  [ 13. 799.]
#  [ 13. 798.]
#  [ 13. 797.]
#  [ 12. 799.]
#  [ 13. 800.]]
# Suche Nachbarn.
# Die Nachbarn sind:
# [[ -1  -1]
#  [ 12 799]
#  [ 12 800]
#  [ 12 801]
#  [ 13 799]
#  [ 13 801]
#  [ 14 799]
#  [ 14 800]
#  [ 14 801]]
# Ueberpruefe, ob Punkt ueber Schwellwert liegt.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-150-35b79b7e4702> in <module>()
# ----> 1 filled_basins = find_basins(pixel_structure,centers,np.max(bt_quant).astype("int"),max_depth,basins,bt_quant,saliency)
#
# <ipython-input-8-06385f3ca22a> in find_basins(pixel_structure, centers, max_level, max_depth, basins, quantised_array, saliency)
#       9                 if basins[int(np.rint(center[0])),
#      10                           int(np.rint(center[1]))] < 0 :
# ---> 11                     new_basin = capture_basin(basins,quantised_array,center[0],center[1],basin_number,saliency,hlevel)
#      12
#      13                     b_idx = np.where(new_basin==basin_number)
#
# _cython_magic_4c26d62cbe6def7615a2e41e5e352cfd.pyx in _cython_magic_4c26d62cbe6def7615a2e41e5e352cfd.capture_basin()
#
# _cython_magic_4c26d62cbe6def7615a2e41e5e352cfd.pyx in _cython_magic_4c26d62cbe6def7615a2e41e5e352cfd.capture_basin()
#
# IndexError: Out of bounds on buffer access (axis 1)

# %%
plt.imshow(filled_basins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-4d86af772abe> in <module>()
# ----> 1 plt.imshow(filled_basins)
#
# NameError: name 'filled_basins' is not defined
