# %%
import pandas as pd
import numpy as np
import glob
import os
import cartopy.crs as ccrs
import cartopy.feature as cf
import matplotlib.pyplot as plt
from functions.fun_projection import *

os.environ['TZ'] = 'UTC'

# %%
doi = "2021-06-02"

y_oi = doi.split('-')[0]
m_oi = doi.split('-')[1]
d_oi = doi.split('-')[2]

# %%
# # convert geographic coordinates to UTM coordinates
# fs = glob.glob("/Users/nicobader/Documents/Uni_Leipzig/master_thesis/analysis/tracks/data/"+y_oi+"/"+m_oi+"/"+d_oi+"/*")

# for i in np.arange(0,len(fs),1):
#    # open track data
#    track = pd.read_csv(fs[i])
#    # transform to UTM coordinates (Zone 32)
#    for k in np.arange(0,len(track),1):
#        utm = project([track.longitude[k],track.latitude[k]])
#        if utm[0] == 32:
#            track.longitude[k] = utm[2]
#            track.latitude[k] = utm[3]
#        else:
#            ax = plt.axes(projection = ccrs.UTM(zone = 32))
#            ax.set_extent([4.708, 16.269 , 46.552, 55.691], crs=ccrs.PlateCarree())
#            ax33 = plt.axes(projection = ccrs.UTM(zone = 33))
#            ax33.set_extent([4.708, 16.269 , 46.552, 55.691], crs=ccrs.PlateCarree())
#            track.longitude[k] = ax.get_xlim()[0]+(utm[2]-ax33.get_xlim()[0])
#            track.latitude[k] = utm[3]
#    track.to_csv("/Users/nicobader/Documents/Uni_Leipzig/master_thesis/analysis/tracks/data/"+y_oi+"/"+m_oi+"/"+d_oi+"/UTM_Track_"+str(i+1)+".csv",index=False)
# Out:
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
# plot tracks
fs = glob.glob("/Users/nicobader/Documents/Uni_Leipzig/master_thesis/analysis/tracks/data/"+y_oi+"/"+m_oi+"/"+d_oi+"/UTM_*")

plt.figure(figsize=(15,16))
ax = plt.axes(projection = ccrs.UTM(zone = 32))
ax.set_extent([4.708, 16.269 , 46.552, 55.691], crs=ccrs.PlateCarree())
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.3, linestyle='--')
gl.xlabels_top = False
gl.xlabel_style = {'size': 14}
gl.ylabel_style = {'size': 14}
gl.ylabels_right = False
ax.add_feature(cf.COASTLINE)
ax.add_feature(cf.BORDERS, linewidth = 1.2)
ax.add_feature(cf.STATES, linewidth = 0.1)
ax.text(ax.get_xlim()[0]+((ax.get_xlim()[1]-ax.get_xlim()[0])*0.115), ax.get_ylim()[1]-((ax.get_ylim()[1]-ax.get_ylim()[0])*0.04), doi, ha = 'center', fontweight = 'bold', fontsize=15,bbox=dict(facecolor='white', edgecolor='grey', pad=5.0, alpha = 0.7))

for i in np.arange(0,len(fs),1):
    # open track data
    track = pd.read_csv(fs[i])
    # transform to UTM coordinates (Zone 32)
    plt.plot(track.longitude, track.latitude, linewidth = 1.7, color = 'darkred')

plt.savefig('/Users/nicobader/Documents/Uni_Leipzig/master_thesis/analysis/tracks/output/plots/tracks_'+y_oi+m_oi+d_oi+'.png', dpi = 400, facecolor = 'white', transparency = False)
# Out:
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "transparency" which is no longer supported as of 3.3 and will become an error two minor releases later

# %%
sed = ['2021-06-01','2021-06-02','2021-06-04','2021-06-05','2021-06-08','2021-06-18','2021-06-21','2021-06-22','2021-07-13','2021-07-25','2021-07-26']

plt.figure(figsize=(15,16))
ax = plt.axes(projection = ccrs.UTM(zone = 32))
ax.set_extent([4.708, 16.269 , 46.552, 55.691], crs=ccrs.PlateCarree())
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.3, linestyle='--')
gl.xlabels_top = False
gl.xlabel_style = {'size': 14}
gl.ylabel_style = {'size': 14}
gl.ylabels_right = False
ax.add_feature(cf.COASTLINE)
ax.add_feature(cf.BORDERS, linewidth = 1.2)
ax.add_feature(cf.STATES, linewidth = 0.1)
#ax.text(ax.get_xlim()[0]+((ax.get_xlim()[1]-ax.get_xlim()[0])*0.115), ax.get_ylim()[1]-((ax.get_ylim()[1]-ax.get_ylim()[0])*0.04), doi, ha = 'center', fontweight = 'bold', fontsize=15,bbox=dict(facecolor='white', edgecolor='grey', pad=5.0, alpha = 0.7))


for i in np.arange(0,len(sed),1):
    doi = sed[i]

    y_oi = doi.split('-')[0]
    m_oi = doi.split('-')[1]
    d_oi = doi.split('-')[2]

    fs = glob.glob("/Users/nicobader/Documents/Uni_Leipzig/master_thesis/analysis/tracks/data/"+y_oi+"/"+m_oi+"/"+d_oi+"/UTM_*")

    for i in np.arange(0,len(fs),1):
        # open track data
        track = pd.read_csv(fs[i])
        # transform to UTM coordinates (Zone 32)
        plt.plot(track.longitude, track.latitude, linewidth = 1.7)

plt.savefig('/Users/nicobader/Documents/Uni_Leipzig/master_thesis/analysis/tracks/output/plots/all_tracks.png', dpi = 400, facecolor = 'white', transparency = False)
# Out:
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /Users/nicobader/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "transparency" which is no longer supported as of 3.3 and will become an error two minor releases later
